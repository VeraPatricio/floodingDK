# %% [markdown]
# ## Overliew

# %%
# %matplotlib widget
import matplotlib.pylab as plt
import seaborn as sns

import numpy as np

import pandas as pd

import re

from tqdm import tqdm
import glob

import geopy
import rasterio
from owslib.wms import WebMapService
import folium

# %% [markdown]
# ## Floading maps
#
# https://gis.nst.dk/server/rest/services/ekstern
#
# ADD SOME INFO

# %%
df_flood_maps = pd.read_csv('Plantrin_2.csv')
df_flood_maps.head(20)
# Out:
#               zone                                                url
# 0         Aabenraa  https://gis.nst.dk/server/services/ekstern/Aab...
# 1          Esbjerg  https://gis.nst.dk/server/services/ekstern/Esb...
# 2       Fredericia  https://gis.nst.dk/server/services/ekstern/Fre...
# 3        Holstebro  https://gis.nst.dk/server/services/ekstern/Hol...
# 4       Juelsminde  https://gis.nst.dk/server/services/ekstern/Jue...
# 5     Kobenhavn_NS  https://gis.nst.dk/server/services/ekstern/Kob...
# 6   Kobenhavn_Nord  https://gis.nst.dk/server/services/ekstern/Koe...
# 7    Kobenhavn_Syd  https://gis.nst.dk/server/services/ekstern/Koe...
# 8          Kolding  https://gis.nst.dk/server/services/ekstern/Kol...
# 9          Korsoer  https://gis.nst.dk/server/services/ekstern/Kor...
# 10           Koege  https://gis.nst.dk/server/services/ekstern/Koe...
# 11          Nyborg  https://gis.nst.dk/server/services/ekstern/Nyb...
# 12          Odense  https://gis.nst.dk/server/services/ekstern/Ode...
# 13    RandersFjord  https://gis.nst.dk/server/services/ekstern/Ran...
# 14       Skaerbaek  https://gis.nst.dk/server/services/ekstern/Ska...
# 15      Sydlolland  https://gis.nst.dk/server/services/ekstern/Syd...
# 16           Vejle  https://gis.nst.dk/server/services/ekstern/Vej...
# 17      Vordinborg  https://gis.nst.dk/server/services/ekstern/Vor...

# %%
# Quick fix. These two are not in WMS format. Needs to be fixed later
df_flood_maps.drop([6,7], inplace=True);

# %% [markdown]
# With the owmlib we can check what data and methods are available
#
# (to get the available data formats: wms.getOperationByName('GetMap').formatOptions)
#
# Here I'm just checking the number of the layers we are interested in

# %%
wms = WebMapService('https://gis.nst.dk/server/services/ekstern/Kobenhavn_NS_Plantrin2/MapServer/WmsServer')

for layer_nb in wms.contents:
    print('%s %40s %s'%(layer_nb,wms[layer_nb].title,wms[layer_nb].crsOptions))
# Out:
# 1                         Risikoområde_KHS ['EPSG:4326', 'EPSG:25832']
# 4 Kulturarv_Seværdige_Fortidsminder_punkter_KHS ['EPSG:4326', 'EPSG:25832']
# 5 Kulturarv_Seværdige_Fortidsminder_areal_KHS ['EPSG:4326', 'EPSG:25832']
# 6                     Kulturarv_Kirker_KHS ['EPSG:4326', 'EPSG:25832']
# 7          Kulturarv_Fredede_Bygninger_KHS ['EPSG:4326', 'EPSG:25832']
# 8      Kulturarv_Fortidsminder_punkter_KHS ['EPSG:4326', 'EPSG:25832']
# 9        Kulturarv_Fortidsminder_areal_KHS ['EPSG:4326', 'EPSG:25832']
# 10                   Bes_sten_jorddiger_KHS ['EPSG:4326', 'EPSG:25832']
# 11                   Begravelsesomraade_KHS ['EPSG:4326', 'EPSG:25832']
# 13                     Vandvaerksboring_KHS ['EPSG:4326', 'EPSG:25832']
# 14 Miljoeinteresser_Vandforsyningsboring_KHS ['EPSG:4326', 'EPSG:25832']
# 15          Miljoeinteresser_Natura2000_KHS ['EPSG:4326', 'EPSG:25832']
# 16     Miljoeinteresser_Beskyttet_natur_KHS ['EPSG:4326', 'EPSG:25832']
# 17 Miljoeinteresser_Aktiv_vandindvinding_KHS ['EPSG:4326', 'EPSG:25832']
# 19                   Risikovirksomheder_KHS ['EPSG:4326', 'EPSG:25832']
# 21                            København Syd ['EPSG:4326', 'EPSG:25832']
# 23                     Beredskab_Politi_KHS ['EPSG:4326', 'EPSG:25832']
# 24                 Beredskab_Hospitaler_KHS ['EPSG:4326', 'EPSG:25832']
# 25           Beredskab_Beredskabscentre_KHS ['EPSG:4326', 'EPSG:25832']
# 27        Berørte_indbyggere_KHS_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 28        Berørte_indbyggere_KHS_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 29        Berørte_indbyggere_KHS_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 30        Berørte_indbyggere_KHS_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 31        Berørte_indbyggere_KHS_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 32         Berørte_indbyggere_KHS_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 34 Kritisk_Infrastruktur_Vandforsyninger_KHS ['EPSG:4326', 'EPSG:25832']
# 35  Kritisk_Infrastruktur_Tranformation_KHS ['EPSG:4326', 'EPSG:25832']
# 36 Kritisk_Infrastruktur_Rensningsanlæg_KHS ['EPSG:4326', 'EPSG:25832']
# 37 Kritisk_Infrastruktur_Kraftvarmeværker_KHS ['EPSG:4326', 'EPSG:25832']
# 38     Ejendomme_forsyninger_KHS_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 39     Ejendomme_forsyninger_KHS_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 40     Ejendomme_forsyninger_KHS_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 41     Ejendomme_forsyninger_KHS_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 42     Ejendomme_forsyninger_KHS_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 43      Ejendomme_forsyninger_KHS_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 46                    Husdyr_KHS_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 47                    Husdyr_KHS_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 48                    Husdyr_KHS_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 49                    Husdyr_KHS_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 50                    Husdyr_KHS_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 51                     Husdyr_KHS_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 53                  Afgrøder_KHS_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 54                  Afgrøder_KHS_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 55                  Afgrøder_KHS_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 56                  Afgrøder_KHS_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 57                  Afgrøder_KHS_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 58                   Afgrøder_KHS_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 60             Infrastruktur_KHS_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 61             Infrastruktur_KHS_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 62             Infrastruktur_KHS_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 63             Infrastruktur_KHS_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 64             Infrastruktur_KHS_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 65              Infrastruktur_KHS_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 67            Virksomhedstab_KHS_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 68            Virksomhedstab_KHS_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 69            Virksomhedstab_KHS_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 70            Virksomhedstab_KHS_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 71            Virksomhedstab_KHS_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 72             Virksomhedstab_KHS_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 74                IndboSkade_KHS_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 75                IndboSkade_KHS_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 76                IndboSkade_KHS_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 77                IndboSkade_KHS_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 78                IndboSkade_KHS_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 79                 IndboSkade_KHS_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 81             Bygningsskade_KHS_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 82             Bygningsskade_KHS_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 83             Bygningsskade_KHS_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 84             Bygningsskade_KHS_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 85             Bygningsskade_KHS_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 86              Bygningsskade_KHS_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 89                     Dybde_KHS_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 90                     Dybde_KHS_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 91                     Dybde_KHS_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 92                     Dybde_KHS_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 93                     Dybde_KHS_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 94                      Dybde_KHS_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 96                Udbredelse_KHS_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 97                Udbredelse_KHS_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 98                Udbredelse_KHS_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 99                Udbredelse_KHS_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 100                Udbredelse_KHS_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 101                 Udbredelse_KHS_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 103     Total_økonomisk_skade_KHS_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 104     Total_økonomisk_skade_KHS_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 105     Total_økonomisk_skade_KHS_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 106     Total_økonomisk_skade_KHS_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 107     Total_økonomisk_skade_KHS_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 108      Total_økonomisk_skade_KHS_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 110                    Risiko_KHS_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 111                    Risiko_KHS_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 112                    Risiko_KHS_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 113                    Risiko_KHS_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 114                    Risiko_KHS_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 115                     Risiko_KHS_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 117                         Risikoområde_KHN ['EPSG:4326', 'EPSG:25832']
# 120 Kulturarv_Seværdige_Fortidsminder_areal_KHN ['EPSG:4326', 'EPSG:25832']
# 121                     Kulturarv_Kirker_KHN ['EPSG:4326', 'EPSG:25832']
# 122          Kulturarv_Fredede_Bygninger_KHN ['EPSG:4326', 'EPSG:25832']
# 123      Kulturarv_Fortidsminder_punkter_KHN ['EPSG:4326', 'EPSG:25832']
# 124        Kulturarv_Fortidsminder_areal_KHN ['EPSG:4326', 'EPSG:25832']
# 125                   Bes_sten_jorddiger_KHN ['EPSG:4326', 'EPSG:25832']
# 126                   Begravelsesomraade_KHN ['EPSG:4326', 'EPSG:25832']
# 128                     Vandvaerksboring_KHN ['EPSG:4326', 'EPSG:25832']
# 129 Miljoeinteresser_Vandforsyningsboring_KHN ['EPSG:4326', 'EPSG:25832']
# 130          Miljoeinteresser_Natura2000_KHN ['EPSG:4326', 'EPSG:25832']
# 131     Miljoeinteresser_Beskyttet_natur_KHN ['EPSG:4326', 'EPSG:25832']
# 132 Miljoeinteresser_Aktiv_vandindvinding_KHN ['EPSG:4326', 'EPSG:25832']
# 134                   Risikovirksomheder_KHN ['EPSG:4326', 'EPSG:25832']
# 136                           København Nord ['EPSG:4326', 'EPSG:25832']
# 138                     Beredskab_Politi_KHN ['EPSG:4326', 'EPSG:25832']
# 139                 Beredskab_Hospitaler_KHN ['EPSG:4326', 'EPSG:25832']
# 140           Beredskab_Beredskabscentre_KHN ['EPSG:4326', 'EPSG:25832']
# 142        Berørte_indbyggere_KHN_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 143        Berørte_indbyggere_KHN_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 144        Berørte_indbyggere_KHN_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 145        Berørte_indbyggere_KHN_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 146        Berørte_indbyggere_KHN_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 147         Berørte_indbyggere_KHN_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 149 Kritisk_Infrastruktur_Vandforsyninger_KHN ['EPSG:4326', 'EPSG:25832']
# 150  Kritisk_Infrastruktur_Tranformation_KHN ['EPSG:4326', 'EPSG:25832']
# 151 Kritisk_Infrastruktur_Rensningsanlæg_KHN ['EPSG:4326', 'EPSG:25832']
# 152 Kritisk_Infrastruktur_Kraftvarmeværker_KHN ['EPSG:4326', 'EPSG:25832']
# 153     Ejendomme_forsyninger_KHN_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 154     Ejendomme_forsyninger_KHN_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 155     Ejendomme_forsyninger_KHN_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 156     Ejendomme_forsyninger_KHN_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 157     Ejendomme_forsyninger_KHN_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 158      Ejendomme_forsyninger_KHN_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 161                    Husdyr_KHN_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 162                    Husdyr_KHN_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 163                    Husdyr_KHN_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 164                    Husdyr_KHN_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 165                    Husdyr_KHN_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 166                     Husdyr_KHN_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 168                  Afgrøder_KHN_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 169                  Afgrøder_KHN_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 170                  Afgrøder_KHN_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 171                  Afgrøder_KHN_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 172                  Afgrøder_KHN_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 173                   Afgrøder_KHN_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 175             Infrastruktur_KHN_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 176             Infrastruktur_KHN_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 177             Infrastruktur_KHN_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 178             Infrastruktur_KHN_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 179             Infrastruktur_KHN_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 180              Infrastruktur_KHN_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 182            Virksomhedstab_KHN_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 183            Virksomhedstab_KHN_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 184            Virksomhedstab_KHN_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 185            Virksomhedstab_KHN_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 186            Virksomhedstab_KHN_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 187             Virksomhedstab_KHN_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 189                IndboSkade_KHN_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 190                IndboSkade_KHN_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 191                IndboSkade_KHN_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 192                IndboSkade_KHN_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 193                IndboSkade_KHN_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 194                 IndboSkade_KHN_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 196             Bygningsskade_KHN_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 197             Bygningsskade_KHN_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 198             Bygningsskade_KHN_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 199             Bygningsskade_KHN_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 200             Bygningsskade_KHN_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 201              Bygningsskade_KHN_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 204                     Dybde_KHN_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 205                     Dybde_KHN_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 206                     Dybde_KHN_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 207                     Dybde_KHN_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 208                     Dybde_KHN_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 209                      Dybde_KHN_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 211                Udbredelse_KHN_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 212                Udbredelse_KHN_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 213                Udbredelse_KHN_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 214                Udbredelse_KHN_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 215                Udbredelse_KHN_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 216                 Udbredelse_KHN_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 218     Total_økonomisk_skade_KHN_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 219     Total_økonomisk_skade_KHN_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 220     Total_økonomisk_skade_KHN_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 221     Total_økonomisk_skade_KHN_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 222     Total_økonomisk_skade_KHN_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 223      Total_økonomisk_skade_KHN_MT20_2019 ['EPSG:4326', 'EPSG:25832']
# 225                    Risiko_KHN_MTEXT_2115 ['EPSG:4326', 'EPSG:25832']
# 226                    Risiko_KHN_MT100_2115 ['EPSG:4326', 'EPSG:25832']
# 227                    Risiko_KHN_MT100_2065 ['EPSG:4326', 'EPSG:25832']
# 228                    Risiko_KHN_MTEXT_2019 ['EPSG:4326', 'EPSG:25832']
# 229                    Risiko_KHN_MT100_2019 ['EPSG:4326', 'EPSG:25832']
# 230                     Risiko_KHN_MT20_2019 ['EPSG:4326', 'EPSG:25832']

# %%
def check_layer_number(url,layer_name):
    wms = WebMapService(url+'/WmsServer')
    layer_titles = [wms[layer_nb].title for layer_nb in wms.contents]
    layer_number = [layer_nb for layer_nb in wms.contents if re.match(layer_name,wms[layer_nb].title) ]
    return layer_number
   
df_flood_maps['Udbredelse_MT20_2019'] = df_flood_maps.url.apply(lambda x: check_layer_number(x,'Udbredelse_\w+_MT20_2019'))

# %%
df_flood_maps.head(20)
# Out:
#             zone                                                url  \
# 0       Aabenraa  https://gis.nst.dk/server/services/ekstern/Aab...
# 1        Esbjerg  https://gis.nst.dk/server/services/ekstern/Esb...
# 2     Fredericia  https://gis.nst.dk/server/services/ekstern/Fre...
# 3      Holstebro  https://gis.nst.dk/server/services/ekstern/Hol...
# 4     Juelsminde  https://gis.nst.dk/server/services/ekstern/Jue...
# 5   Kobenhavn_NS  https://gis.nst.dk/server/services/ekstern/Kob...
# 8        Kolding  https://gis.nst.dk/server/services/ekstern/Kol...
# 9        Korsoer  https://gis.nst.dk/server/services/ekstern/Kor...
# 10         Koege  https://gis.nst.dk/server/services/ekstern/Koe...
# 11        Nyborg  https://gis.nst.dk/server/services/ekstern/Nyb...
# 12        Odense  https://gis.nst.dk/server/services/ekstern/Ode...
# 13  RandersFjord  https://gis.nst.dk/server/services/ekstern/Ran...
# 14     Skaerbaek  https://gis.nst.dk/server/services/ekstern/Ska...
# 15    Sydlolland  https://gis.nst.dk/server/services/ekstern/Syd...
# 16         Vejle  https://gis.nst.dk/server/services/ekstern/Vej...
# 17    Vordinborg  https://gis.nst.dk/server/services/ekstern/Vor...
#
#    Udbredelse_MT20_2019
# 0                  [99]
# 1                 [101]
# 2                  [96]
# 3                  [79]
# 4                  [99]
# 5            [101, 216]
# 8                 [109]
# 9                 [100]
# 10                 [99]
# 11                [101]
# 12                [109]
# 13                 [80]
# 14                 [96]
# 15                [120]
# 16                [108]
# 17                 [99]

# %% [markdown]
# ## Save all layers

# %%
def save_file(url,layer,size,crs,dir):
    
    wms = WebMapService(url+'/WmsServer')
    srs = wms[layer].crsOptions
    bbox = wms[layer].boundingBoxWGS84 
    output_name = wms[layer].title
    
    if crs not in srs:
        print('CRS not available (available options:)',srs)
        pass
        
    # Get the image from the server
    img = wms.getmap(layers=[layer],
                     styles=['default'],
                     srs=crs,
                     bbox=bbox,
                     size=size,
                     transparent=True,
                     format='image/tiff'
                    )
    
    # Clumsy, but the img object is not an array, so it needs to be saved to a file
    with open(dir+output_name+'.tiff', 'wb') as out:
        out.write(img.read())
       
    # Re-open the same image in rasterio to georeference it
    # for tiff save only one band
    img_array = rasterio.open(dir+output_name+'.tiff').read(1).squeeze() 
    img_shape = img_array.shape
    dst_transform = rasterio.transform.from_bounds(west = bbox[0],
                                                   south = bbox[1],
                                                   east = bbox[2],
                                                   north = bbox[3],
                                                   width=img_shape[1], height=img_shape[0])
    # Write it out to a file.
    with rasterio.open(dir+output_name+'_georef.tiff', 'w', driver='GTiff',
                                  width=img_shape[1], height=img_shape[0],
                                  count=1, dtype=np.uint8, nodata=0,
                                  transform=dst_transform, crs=crs) as dst:
        dst.write(img_array.astype(np.uint8), indexes=1)

# %%
for idx,row in tqdm(df_flood_maps.iterrows()):
    for layer in row.Udbredelse_MT20_2019:
        print(row.url,layer)
        save_file(row.url,
                  layer=layer,
                  size=(5000,5000),
                  crs='EPSG:4326',
                  dir='Udbredelse_MT20_2019_HR/')
# Out:
# 0it [00:00, ?it/s]
# https://gis.nst.dk/server/services/ekstern/Aabenraa_Plantrin2/MapServer 99
# 0it [00:01, ?it/s]
# ---------------------------------------------------------------------------
# ServiceException                          Traceback (most recent call last)
# <ipython-input-246-8f3772182eef> in <module>
#       6                   size=(5000,5000),
#       7                   crs='EPSG:4326',
# ----> 8                   dir='Udbredelse_MT20_2019_HR/')
#
# <ipython-input-243-5d555d07e80a> in save_file(url, layer, size, crs, dir)
#      17                      size=size,
#      18                      transparent=True,
# ---> 19                      format='image/tiff'
#      20                     )
#      21
#
# ~/Library/Python/3.7/lib/python/site-packages/owslib/map/wms111.py in getmap(self, layers, styles, srs, bbox, format, size, time, transparent, bgcolor, exceptions, method, timeout, **kwargs)
#     260         self.request = bind_url(base_url) + data
#     261
# --> 262         u = openURL(base_url, data, method, timeout=timeout or self.timeout, auth=self.auth)
#     263
#     264         # check for service exceptions, and return
#
# ~/Library/Python/3.7/lib/python/site-packages/owslib/util.py in openURL(url_base, data, method, cookies, username, password, timeout, headers, verify, cert, auth)
#     229             if serviceException is not None:
#     230                 # and we need to deal with some message nesting
# --> 231                 raise ServiceException('\n'.join([t.strip() for t in serviceException.itertext() if t.strip()]))
#     232
#     233     return ResponseWrapper(req)
#
# ServiceException: Parameter 'width' contains unacceptable value.

# %% [markdown]
# ## Plot all with folium

# %%
m = folium.Map([55.39594, 10.38831])

group = folium.FeatureGroup(name='Test')


#for file in glob.glob('Udbredelse_MT20_2019/*geo*'):
for file in glob.glob('Udbredelse_MT20_2019_HR/*geo*'):
    
    print(file)
    # Add layer
    rio_img = rasterio.open(file)
    bbox = rio_img.bounds

    group.add_child(folium.raster_layers.ImageOverlay(
                    name=file,
                    image = rio_img.read().squeeze(),
                    #[[lat_min, lon_min], [lat_max, lon_max]]
                    bounds = [[bbox.bottom,bbox.left],[bbox.top,bbox.right]],
                    opacity=0.8,
                    show=True,
                    overlay=True,
                    interactive=True,
                    )
                   )
                    
m.add_child(group)
                    
folium.LayerControl().add_to(m)

## Add a point
folium.Marker([55.39594, 10.38831], popup='this is a marker').add_to(m)

m
